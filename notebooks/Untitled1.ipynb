# %%
import pandas as pd
df=pd.read_excel("C:\\Users\\Bhawesh\\Downloads\\Course offerings.xlsx",sheet_name="Electrical",header=3)
df.head()
# Out:
#    S. no.  Department offering the course Code of the course  \
# 0      1.0                             EE         EFD002U1M
# 1      NaN                            NaN                NaN
# 2      NaN                            NaN                NaN
# 3      NaN                            NaN                NaN
# 4      2.0                             EE          EED001U2M
#
#                Name of the course Course structure (L-T/D-P: C)  \
# 0    Basic Electrical Engineering                      3-1-0: 3
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                             NaN                           NaN
# 4  Network Analysis and Synthesis                      3-1-0: 3
#
#   Categaory of the course  (IC/DC/DE/IE/CE)  \
# 0                                        IC
# 1                                       NaN
# 2                                       NaN
# ...

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [S. no. , Department offering the course, Code of the course, Name of the course, Course structure (L-T/D-P: C), Categaory of the course  (IC/DC/DE/IE/CE), Name and code of the prerequisite course/s if any , Department and entry year of the students to whom the course will be offered, To be offered to UG/ M.Tech./Ph.D. students, Course coordinator (Residential), Policy for division of class, Type of class (L/T/P) for every divison, To be running during/after the on-line semester, Course instructor for every type of class (Separate row for every type of class and divison), Number of total L/T/P  classes to be taken in the entire semester, Expected maximum number of students per type of class, In the case of more than one instructors per type of class, can the classes run in parallel? (Y/N/NA), Is it only for the backlog students?  (Y/N), Any special requirement, Unnamed: 19, Unnamed: 20]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['S. no. ', 'Department offering the course', 'Code of the course',
#        'Name of the course', 'Course structure (L-T/D-P: C)',
#        'Categaory of the course  (IC/DC/DE/IE/CE)',
#        'Name and code of the prerequisite course/s if any ',
#        'Department and entry year of the students to whom the course will be offered',
#        'To be offered to UG/ M.Tech./Ph.D. students',
#        'Course coordinator (Residential)', 'Policy for division of class',
#        'Type of class (L/T/P) for every divison',
#        'To be running during/after the on-line semester',
#        'Course instructor for every type of class (Separate row for every type of class and divison)',
#        'Number of total L/T/P  classes to be taken in the entire semester',
#        'Expected maximum number of students per type of class',
#        'In the case of more than one instructors per type of class, can the classes run in parallel? (Y/N/NA)',
# ...

# %%
df[(df[Department offering the course] == "EE") | (df.C == 10)]
